# %%
import numpy as np

# %%
data = np.load("../data/digits.npy")

# %%
data
# Out:
# array([[0.    , 0.    , 0.3125, ..., 0.    , 0.    , 0.    ],
#        [0.    , 0.    , 0.    , ..., 0.625 , 0.    , 0.    ],
#        [0.    , 0.    , 0.    , ..., 1.    , 0.5625, 0.    ],
#        ...,
#        [0.    , 0.    , 0.0625, ..., 0.375 , 0.    , 0.    ],
#        [0.    , 0.    , 0.125 , ..., 0.75  , 0.    , 0.    ],
#        [0.    , 0.    , 0.625 , ..., 0.75  , 0.0625, 0.    ]],
#       shape=(1797, 64), dtype=float32)
